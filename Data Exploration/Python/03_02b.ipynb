# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Visualisation

# %% [markdown]
# ### Learning objectives

# %% [markdown]
# Visualising data is a crutial step of data exploration phase, many hidden patterns of data can be identified whith graphs and charts. There are four groups of charts we can use while exploring data
# * Comparison graphs: Ex Boxplot
# * Relationship graphs: Ex Scratter plot
# * Distribution graphs: Histogram
# * Composition graphs: Ex Bar chart, Stacked bar chart, Pie chart

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load the dataset

# %%
supermarket_sales = pd.read_csv('../data/detailed_supermarket_sales.csv')
supermarket_sales.head()
# Out:
#   Invoice ID Branch       City Customer Type  Gender            Product line  \
# 0   569dac1b      C  Naypyitaw        Normal    Male  Electronic accessories
# 1   8822a33d      A  Naypyitaw        Normal  Female       Sports and travel
# 2   b623fb46      C  Naypyitaw        Member    Male  Electronic accessories
# 3   5c7b5576      C  Naypyitaw        Normal  Female      Food and beverages
# 4   d1241256      A     Yangon        Member    Male       Health and beauty
#
#    Unit price  Quantity   Tax 5%     Total       Dates      Time      Payment  \
# 0       55.10         1   2.7550   57.8550  2024-01-25  23:31:33         Cash
# 1       73.56         8  29.4240  617.9040  2024-07-09  11:10:17  Credit card
# 2       58.09         4  11.6180  243.9780  2024-05-05  01:25:30         Cash
# 3       58.67         5  14.6675  308.0175  2024-08-21  09:36:15         Cash
# 4       48.66         8  19.4640  408.7440  2024-04-20  02:22:53  Credit card
#
# ...

# %% [markdown]
# ### Set up the aesthetics for the plots

# %%
sns.set(style="whitegrid")

# %% [markdown]
# ## Comparison Graph: Boxplot

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='Product line', y='Total', data=supermarket_sales)
plt.title('Boxplot of Total Sales by Product Line')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Relationship Graph: Scatter plot

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='Unit price', y='Quantity', hue="Product line", data=supermarket_sales)
plt.title('Scatterplot of Unit Price vs Quantity by Product Line')
plt.show()

# %% [markdown]
# ## Distribution Graph: Histogram

# %%
plt.figure(figsize=(8, 5))
sns.histplot(supermarket_sales['Total'], bins=20, kde=True)
plt.title('Histogram of Total Sales')
plt.xlabel('Total Sales')
plt.show()

# %% [markdown]
# ## Composition Graph: Bar chart

# %%
plt.figure(figsize=(8, 5))
supermarket_sales['Product line'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Barplot of Product Line Distribution')
plt.ylabel('Count')
plt.xlabel('Product Line')
plt.show()

# %% [markdown]
# ## Composition Graph: Stacked Bar chart

# %%
plt.figure(figsize=(8, 5))
supermarket_sales.groupby(["Product line","Gender"]).size().unstack().plot(kind='bar', stacked=True)
plt.title('Stacked Barplot of Product Line Distribution by Gender')
plt.ylabel('Count')
plt.xlabel("Gender")
plt.show()

# %% [markdown]
# ## Composition Graph: Pie chart

# %%
plt.figure(figsize=(8, 5))
supermarket_sales["Gender"].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['skyblue', 'pink'])
plt.title('Pie Chart of Gender Distribution')
plt.ylabel('')
plt.show()
